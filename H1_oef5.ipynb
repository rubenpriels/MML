# %%
import numpy as np

# %%
def cosinus_similariteit(vector1, vector2):
    assert len(vector1.shape) == 1, "eerste is geen vector"
    assert len(vector2.shape) == 1, "tweede is geen vector"

    assert vector1.ndim == 1, "eerste is geen vector"
    assert vector2.ndim == 1, "tweede is geen vector"
    # vector1Normalized = vector1/np.linalg.norm(vector1)
    # vector2Normalized = vector2/np.linalg.norm(vector2)

    result = np.dot(vector1, vector2) / (np.linalg.norm(vector1))
